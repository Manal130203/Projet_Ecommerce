# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Manal\Documents\Projet_Ecommerce

# %%
import os

os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'data',
#  'DECISIONS.md',
#  'notebooks',
#  'profiling.ipynb',
#  'quality_tests.ipynb',
#  'README.md',
#  'reports',
#  'requirements.txt',
#  'src',
#  'Untitled.ipynb']

# %%
# !dir data\silver
# Out:
#  Le volume dans le lecteur C n'a pas de nom.
#  Le num‚ro de s‚rie du volume est 8891-EC84
#
#  R‚pertoire de C:\Users\Manal\Documents\Projet_Ecommerce\data\silver
#
# 23/05/2026  19:54    <DIR>          .
# 23/05/2026  20:11    <DIR>          ..
# 23/05/2026  19:54        36.553.993 retail_clean.csv
# 23/05/2026  19:54           440.459 shipping_clean.csv
#                2 fichier(s)       36.994.452 octets
#                2 R‚p(s)  210.248.155.136 octets libres

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Manal\Documents\Projet_Ecommerce

# %%
import pandas as pd

retail_clean = pd.read_csv(
    "data/silver/retail_clean.csv"
)

retail_clean.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
retail_clean["CustomerID"].isnull().sum()
# Out:
# np.int64(0)

# %%
retail_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
codes_to_remove = [
    "POST",
    "D",
    "C2",
    "M",
    "BANK CHARGES"
]

retail_clean["StockCode"].isin(
    codes_to_remove
).sum()
# Out:
# np.int64(0)

# %%
retail_clean["InvoiceDate"].isnull().sum()
# Out:
# np.int64(0)

# %%
print("TEST CustomerID : PASS")
print("TEST Doublons : PASS")
print("TEST UnitPrice : PASS")
print("TEST StockCode : PASS")
print("TEST InvoiceDate : PASS")
print("VALIDATION SILVER REUSSIE")
# Out:
# TEST CustomerID : PASS
# TEST Doublons : PASS
# TEST UnitPrice : PASS
# TEST StockCode : PASS
# TEST InvoiceDate : PASS
# VALIDATION SILVER REUSSIE
